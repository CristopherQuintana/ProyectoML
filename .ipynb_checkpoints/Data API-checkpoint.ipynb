# %%
import requests
import sqlite3
from datetime import datetime, timedelta

# Configuración de la conexión a la base de datos SQLite
conn = sqlite3.connect('tokens.db')
c = conn.cursor()

# Método para obtener el access_token y refresh_token de la base de datos
def get_tokens():
    c.execute("SELECT * FROM tokens")
    tokens = c.fetchone()
    if tokens is None:
        return None
    access_token, refresh_token, expiration_date = tokens
    expiration_date = datetime.strptime(expiration_date, '%Y-%m-%d %H:%M:%S')
    return access_token, refresh_token, expiration_date

# Método para guardar el access_token y refresh_token en la base de datos
def save_tokens(access_token, refresh_token, expiration_date):
    c.execute("DELETE FROM tokens")
    c.execute("INSERT INTO tokens VALUES (?, ?, ?)",
            (access_token, refresh_token, expiration_date))
    conn.commit()

# Método para obtener un nuevo access_token y refresh_token
def get_new_tokens(refresh_token):
    url = "https://api.mercadolibre.com/oauth/token"
    payload = {
        "grant_type": "refresh_token",
        "client_id": "5030313997317379",
        "client_secret": "zTJax3dLAiog35gQdaOVEhTSwxXxbTTY",
        "refresh_token": refresh_token
    }
    response = requests.post(url, data=payload)
    response.raise_for_status()
    data = response.json()
    access_token = data['access_token']
    refresh_token = data['refresh_token']
    expires_in = data['expires_in']
    expiration_date = datetime.now() + timedelta(seconds=expires_in)
    expiration_date_str = expiration_date.strftime('%Y-%m-%d %H:%M:%S')
    save_tokens(access_token, refresh_token, expiration_date_str)
    return access_token, refresh_token, expiration_date_str

# Método para hacer la petición con el access_token
def make_request(access_token, url):
    headers = {"Authorization": f"Bearer {access_token}"}
    response = requests.get(url, headers=headers)
    response.raise_for_status()
    data = response.json()
    return data

# Método para hacer una petición a la main
def do_request(url, params=None):
    tokens = get_tokens()
    if tokens is None or tokens[2] < datetime.now():
        refresh_token = tokens[1] if tokens is not None else input("Ingrese refresh_token: ")
        access_token, refresh_token, expiration_date = get_new_tokens(refresh_token)
    else:
        access_token, refresh_token, expiration_date = tokens
    
    headers = {
        "Authorization": f"Bearer {access_token}"
    }
    
    response = requests.get(url, params=params, headers=headers)
    data = response.json()
    
    return data

url = "https://api.mercadolibre.com/trends/MLC"
url2 = "https://api.mercadolibre.com/sites/MLC/search?category=MLC82067"
url3 = "https://api.mercadolibre.com/sites/MLC/search?category=MLC1648&offset=50"
url4 = "https://api.mercadolibre.com/sites/MLC/search?category=MLC1648&offset=100"
url5 = "https://api.mercadolibre.com/highlights/$SITE_ID/category/$CATEGORY_ID"

# datos json
datos_json = do_request(url2)['results']
# Cerrar la conexión a la base de datos al terminar
conn.close()

# %%
import pandas as pd
import json
datos_filtrados = []

for producto in datos_json:
    producto_filtrado = {
        "id": producto["id"],
        "title": producto["title"],
        "condition": producto["condition"],
        "thumbnail_id": producto["thumbnail_id"],
        "listing_type_id": producto["listing_type_id"],
        "permalink": producto["permalink"],
        "sold_quantity": producto["sold_quantity"],
        "available_quantity": producto["available_quantity"],
        "price": producto["price"],
        "original_price": producto["original_price"]
    }
    datos_filtrados.append(producto_filtrado)
    
df = pd.DataFrame(datos_filtrados)
df.head(50)
# Out:
#                id                                              title  \
# 0    MLC933990138  Apple iPad (9ª Generación) 10.2  Wi-fi 64gb - ...
# 1    MLC952312355  Tablet  Samsung Galaxy Tab A A7 Lite Sm-t220 8...
# 2   MLC1758030624  Apple iPad (9ª Generación) 10.2  Wi-fi 64gb - ...
# 3    MLC943586833  Apple iPad (9ª Generación) 10.2  Wi-fi 256gb -...
# 4   MLC1248900108  Tablet  Samsung Galaxy Tab A A7 Lite Sm-t225 8...
# 5   MLC1691643942  Tablet  Lenovo Tab M10 Hd 2nd Gen With Folio C...
# 6   MLC1187798821  Tablet Mlab Kids Play & Learn Se 16gb Rom 2gb ...
# 7    MLC958421903  Tablet  Samsung Galaxy Tab A A7 Lite Sm-t220 8...
# 8   MLC1012514042  Tablet  Con Funda Mlab Glowy 8990 Sketch Pen 1...
# 9   MLC1044991380  Tablet  Samsung Galaxy Tab A A8 Sm-x200 10.5  ...
# 10  MLC1682348226  Apple iPad (10ª Generación) 10,9'' Wi - Fi 64g...
# 11  MLC1059434774  Tablet  Huawei Matepad T 10 Agr-w09 9.7  32gb ...
# 12  MLC1757694428  Apple iPad (9ª Generación) 10.2  Wi-fi 256gb -...
# 13  MLC1289111790  Tablet  Samsung Galaxy Tab S S6 Lite With Book...
# 14  MLC1297011942  Tablet  Xiaomi Mi Lcd Writing Tablet 13.5  13....
# 15   MLC952324654  Tablet  Samsung Galaxy Tab A A7 Lite Sm-t220 8...
# 16  MLC1349858063  Apple iPad Air (5ª Generación) 10.9  Wi-fi 64 ...
# 17  MLC1382015601  Tablet  Con Funda Soymomo Pro Android 9.0 8  3...
# 18   MLC959885603  Tablet  Amazon Fire Hd 8 2020 Kfonwi 8  32gb B...
# 19  MLC1385003711  Tablet Huawei Matepad Se 10.4  2k Fullview 4gb...
# 20  MLC1386638023  Tablet  Samsung Galaxy Tab S S7 Fe With S Pen ...
# 21  MLC1368798813  Tablet  Lenovo Tab M10 Fhd Plus 2nd Gen Tb-x60...
# 22  MLC1264560207  Tablet Gamer Mlab Xkuny 8715 16gb Rom 2gb Ram ...
# 23  MLC1147682560  Tablet Samsung Galaxy Tab A8 Sm-x205 10.5  Con...
# 24  MLC1188401837  Tablet Mlab Mb8 Plus 16gb Rom 2gb Ram 8 Pulgad...
# 25  MLC1382917261  Tablet  Lenovo Tab M10 Fhd Plus 2nd Gen Tb-x60...
# 26  MLC1588239366  Tablet  Samsung Galaxy Tab A A8 Sm-x200 10.5  ...
# 27  MLC1188738546  Tablet Mlab Mb7 16gb Rom 2gb Ram 7 Pulgadas Ip...
# 28  MLC1384043433  Tablet  Lenovo Tab P11 Tb-j606l 11  Con Red Mó...
# 29   MLC977841517  Tablet  Amazon Fire Hd 10 2021 Kftrwi 10.1  32...
# 30  MLC1288887784  Tablet  Samsung Galaxy Tab S S6 Lite With Book...
# 31  MLC1396301385  Apple iPad Air (5ª Generación) 10.9  Wi-fi 64 ...
# 32  MLC1396317001  iPad  Apple   10th Generation 2022 A2696 10.9 ...
# 33  MLC1346624200  Tablet  Samsung Galaxy Tab S S6 Lite Sm-p613 1...
# 34  MLC1386674477  Tablet  Samsung Galaxy Tab S S7 Fe With S Pen ...
# 35   MLC631080995  Tablet  Mlab Cinema 8866 Mbx 10  Con Red Móvil...
# 36  MLC1289053427  Tablet  Samsung Galaxy Tab S S6 Lite With Book...
# 37   MLC922364074  Tablet  Amazon Fire Hd 10 2021 Kftrwi 10.1  32...
# 38  MLC1718017198  Tablet  Xiaomi Redmi Pad 10.61  128gb Graphite...
# 39   MLC502366370     Pizarra Lcd Pizarra Mágica Tablet 8.5 Pulgadas
# 40  MLC1286791087  iPad  Apple   10th Generation 2022 A2696 10.9 ...
# 41  MLC1581497200  iPad  Apple   10th Generation 2022 A2696 10.9 ...
# 42  MLC1689911702  Tablet  Samsung Galaxy Tab A 8.0 2019 Sm-t295 ...
# 43  MLC1382359753  Apple iPad (10ª Generación) 10,9'' Wi - Fi 256...
# 44   MLC986620791  Tablet 10 M-black 4g Ram 6gb Rom 128gb Ranura ...
# 45  MLC1361113911  Tablet  Samsung Galaxy Tab S S6 Lite Sm-p610 1...
# 46  MLC1393068285  Tablet  Lenovo Yoga Tab 11 Yt-j706f 11  128gb ...
# 47   MLC977810208  Tablet  Amazon Fire Hd 10 2021 Kftrwi 10.1  32...
# 48   MLC908532156   Apple iPad De 10,2'' Wi-fi 64 gb (9a Generación)
# 49  MLC1182695364  Tablet  X-view Proton Titanium Hd 10  16gb Gri...
#
#    condition                  thumbnail_id listing_type_id  \
# 0        new  625786-MLU69484160938_052023        gold_pro
# 1        new  688786-MLA47146625523_082021    gold_special
# 2        new  907886-MLU69497668167_052023    gold_special
# 3        new  706956-MLU69486027564_052023        gold_pro
# 4        new  667801-MLA47848605440_102021    gold_special
# 5        new  795476-MLA48642456248_122021    gold_special
# 6        new  601122-MLC52446236804_112022    gold_special
# 7        new  752514-MLA47146849081_082021    gold_special
# 8        new  773627-MLA48644452913_122021    gold_special
# 9        new  945900-MLA50877042155_072022    gold_special
# 10       new  762348-MLC53805602754_022023    gold_special
# 11       new  602613-MLA45257771664_032021        gold_pro
# 12       new  898922-MLU69482631414_052023    gold_special
# 13       new  770830-MLA45821742649_052021    gold_special
# 14       new  983181-MCO48967650742_012022    gold_special
# 15       new  954665-MLA47146793114_082021    gold_special
# 16       new  932838-MLU69497633629_052023    gold_special
# 17       new  605216-MLA47931288759_102021        gold_pro
# 18       new  710740-MLA45264852525_032021    gold_special
# 19       new  700097-MLU69416402120_052023    gold_special
# 20       new  729539-MLA48049063325_102021        gold_pro
# 21       new  724533-MLA45630265092_042021    gold_special
# 22       new  609848-MLC52929222636_122022    gold_special
# 23       new  910700-MLA52261910192_112022    gold_special
# 24       new  664779-MLA52519843335_112022    gold_special
# 25       new  859394-MLA45630184289_042021    gold_special
# 26       new  870191-MLA51468993998_092022    gold_special
# 27       new  961209-MLC52446237974_112022    gold_special
# 28       new  611364-MLA52680076654_122022    gold_special
# 29       new  779155-MLA49274437822_032022    gold_special
# 30       new  912208-MLA45821742655_052021    gold_special
# 31       new  761402-MLU69497652927_052023    gold_special
# 32       new  891613-MLA52988782504_122022    gold_special
# 33       new  792285-MLA53362598654_012023    gold_special
# 34       new  601055-MLA48049070065_102021        gold_pro
# 35       new  697595-MLA45720876072_042021    gold_special
# 36       new  757620-MLA45821559877_052021    gold_special
# 37       new  910953-MLA49274400986_032022    gold_special
# 38       new  970963-MLA52579617825_112022    gold_special
# 39       new  840438-MLC47197506414_082021        gold_pro
# 40       new  764857-MLA52988770506_122022        gold_pro
# 41       new  620034-MLA52988770674_122022    gold_special
# 42       new  834758-MLA41913051534_052020    gold_special
# 43       new  734038-MLA54408249400_032023    gold_special
# 44       new  652616-MLC53584690148_022023    gold_special
# 45       new  832076-MLA45259578147_032021    gold_special
# 46       new  806714-MLA48244069380_112021    gold_special
# 47       new  773086-MLA49274400981_032022    gold_special
# 48       new  616750-MLC48833230605_012022        gold_pro
# 49       new  980222-MLA45257468545_032021        gold_pro
#
#                                             permalink  sold_quantity  \
# 0   https://www.mercadolibre.cl/apple-ipad-9-gener...            500
# 1   https://www.mercadolibre.cl/tablet-samsung-gal...            150
# 2   https://www.mercadolibre.cl/apple-ipad-9-gener...              0
# 3   https://www.mercadolibre.cl/apple-ipad-9-gener...            200
# 4   https://www.mercadolibre.cl/tablet-samsung-gal...            250
# 5   https://www.mercadolibre.cl/tablet-lenovo-tab-...             50
# 6   https://www.mercadolibre.cl/tablet-mlab-kids-p...             25
# 7   https://www.mercadolibre.cl/tablet-samsung-gal...            500
# 8   https://www.mercadolibre.cl/tablet-con-funda-m...            150
# 9   https://www.mercadolibre.cl/tablet-samsung-gal...             50
# 10  https://www.mercadolibre.cl/apple-ipad-10-gene...              5
# 11  https://www.mercadolibre.cl/tablet-huawei-mate...            250
# 12  https://www.mercadolibre.cl/apple-ipad-9-gener...              0
# 13  https://www.mercadolibre.cl/tablet-samsung-gal...            100
# 14  https://www.mercadolibre.cl/tablet-xiaomi-mi-l...             25
# 15  https://www.mercadolibre.cl/tablet-samsung-gal...            250
# 16  https://www.mercadolibre.cl/apple-ipad-air-5-g...              5
# 17  https://www.mercadolibre.cl/tablet-con-funda-s...              5
# 18  https://www.mercadolibre.cl/tablet-amazon-fire...            100
# 19  https://www.mercadolibre.cl/tablet-huawei-mate...              5
# 20  https://www.mercadolibre.cl/tablet-samsung-gal...              5
# 21  https://www.mercadolibre.cl/tablet-lenovo-tab-...              5
# 22  https://www.mercadolibre.cl/tablet-gamer-mlab-...             25
# 23  https://www.mercadolibre.cl/tablet-samsung-gal...              5
# 24  https://www.mercadolibre.cl/tablet-mlab-mb8-pl...              5
# 25  https://www.mercadolibre.cl/tablet-lenovo-tab-...              1
# 26  https://www.mercadolibre.cl/tablet-samsung-gal...              5
# 27  https://www.mercadolibre.cl/tablet-mlab-mb7-16...             25
# 28  https://www.mercadolibre.cl/tablet-lenovo-tab-...              3
# 29  https://www.mercadolibre.cl/tablet-amazon-fire...              3
# 30  https://www.mercadolibre.cl/tablet-samsung-gal...             50
# 31  https://www.mercadolibre.cl/apple-ipad-air-5-g...              0
# 32  https://www.mercadolibre.cl/ipad-apple-10th-ge...              1
# 33  https://www.mercadolibre.cl/tablet-samsung-gal...              5
# 34  https://www.mercadolibre.cl/tablet-samsung-gal...              5
# 35  https://www.mercadolibre.cl/tablet-mlab-cinema...             50
# 36  https://www.mercadolibre.cl/tablet-samsung-gal...             50
# 37  https://www.mercadolibre.cl/tablet-amazon-fire...             25
# 38  https://www.mercadolibre.cl/tablet-xiaomi-redm...              4
# 39  https://articulo.mercadolibre.cl/MLC-502366370...            500
# 40  https://www.mercadolibre.cl/ipad-apple-10th-ge...              3
# 41  https://www.mercadolibre.cl/ipad-apple-10th-ge...              5
# 42  https://www.mercadolibre.cl/tablet-samsung-gal...              4
# 43  https://www.mercadolibre.cl/apple-ipad-10-gene...              5
# 44  https://articulo.mercadolibre.cl/MLC-986620791...             50
# 45  https://www.mercadolibre.cl/tablet-samsung-gal...              5
# 46  https://www.mercadolibre.cl/tablet-lenovo-yoga...              0
# 47  https://www.mercadolibre.cl/tablet-amazon-fire...              1
# 48  https://articulo.mercadolibre.cl/MLC-908532156...            250
# 49  https://www.mercadolibre.cl/tablet-x-view-prot...              5
#
#     available_quantity   price  original_price
# 0                    1  319990        372990.0
# 1                    1  159990        179990.0
# 2                    1  299990             NaN
# 3                  100  489990        527990.0
# 4                  250  138500        144990.0
# 5                    1  169990             NaN
# 6                    1   62388             NaN
# 7                    1  174990             NaN
# 8                    1  101002             NaN
# 9                    1  189990        249990.0
# 10                   1  519990        584990.0
# 11                 250   94990             NaN
# 12                   1  459990             NaN
# 13                  50  369990        429990.0
# 14                  50   29990             NaN
# 15                   1  159990        179990.0
# 16                   1  899990             NaN
# 17                   1  109990             NaN
# 18                   1   84776             NaN
# 19                   1  209990        249990.0
# 20                   1  439990       1035279.0
# 21                   1  169990             NaN
# 22                   1   66490         69990.0
# 23                   1  195852        212883.0
# 24                   1   65002             NaN
# 25                   1  189990        199990.0
# 26                   1  189990        249990.0
# 27                   1   55990             NaN
# 28                   1  269991        299990.0
# 29                   1  141540        148990.0
# 30                   1  369990        429990.0
# 31                   1  599990             NaN
# 32                   1  479990             NaN
# 33                   1  329990             NaN
# 34                   1  449990       1035279.0
# 35                   1  112990        169990.0
# 36                  50  369990        429990.0
# 37                   1  129990        149990.0
# 38                   1  297651        362990.0
# 39                 150    2964          3900.0
# 40                   1  730000             NaN
# 41                   1  496992        699990.0
# 42                   1  149990             NaN
# 43                   1  689990        771990.0
# 44                  50  199990             NaN
# 45                   1  329990             NaN
# 46                   1  246993        379990.0
# 47                   1  142490        149990.0
# 48                 500  319990        372990.0
# 49                   1   69990             NaN

# %%
total_resultados = 1000
resultados_por_pagina = 50
paginas = total_resultados // resultados_por_pagina  # Calcula el número total de páginas

datos_filtrados_full = []

for pagina in range(1, paginas + 1):
    parametros = {
        "offset": (pagina - 1) * resultados_por_pagina,
        "limit": resultados_por_pagina
    }
    respuesta = do_request(url2, parametros)
    datos_pagina = respuesta["results"]

    for producto in datos_pagina:
        producto_filtrado = {
            "id": producto["id"],
            "title": producto["title"],
            "condition": producto["condition"],
            "thumbnail_id": producto["thumbnail_id"],
            "listing_type_id": producto["listing_type_id"],
            "permalink": producto["permalink"],
            "sold_quantity": producto["sold_quantity"],
            "available_quantity": producto["available_quantity"],
            "price": producto["price"],
            "original_price": producto["original_price"]
        }
        datos_filtrados_full.append(producto_filtrado)

df = pd.DataFrame(datos_filtrados_full)
df.head(200)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 12
#       7 for pagina in range(1, paginas + 1):
#       8     parametros = {
#       9         "offset": (pagina - 1) * resultados_por_pagina,
#      10         "limit": resultados_por_pagina
#      11     }
# ---> 12     respuesta = do_request(url2, parametros)
#      13     datos_pagina = respuesta["results"]
#      15     for producto in datos_pagina:
#
# TypeError: do_request() takes 1 positional argument but 2 were given
